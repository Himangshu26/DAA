# %% [markdown]
# ## **Depth First Search**
#
# DFS focuses on the depth of a topological structure. To put it in layman's terms, DFS keeps going forward along the first available branch until it reaches cul-de-sac. Then DFS starts backtracking until it finds an unvisited branch to reach the very end. DFS will repeat the previous two steps until all vertices have been investigated.
#
# Please refer to the website below for details
#
# https://en.wikipedia.org/wiki/Depth-first_search

# %%
class Node:
  def __init__(self, value):
    self.value = value
    self.neighbors = []
graph = {}
for i in range(6):
  node = Node(i)
  graph[i] = node5
graph[0].neighbors.append(1)
graph[0].neighbors.append(2)
graph[1].neighbors.append(3)
graph[1].neighbors.append(4)
graph[2].neighbors.append(5)
def dfs(graph, start, visited):
  visited.add(start)
  print(start)
  for neighbor in graph[start].neighbors:
    if neighbor not in visited:
      dfs(graph, neighbor, visited)
visited = set()
dfs(graph, 0, visited)
# Out:
# 0
# 1
# 3
# 4
# 2
# 5

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.1)

# %%
import graphviz
graph = graphviz.Graph()
graph.node('0')
graph.node('1')
graph.node('2')
graph.node('3')
graph.node('4')
graph.node('5')
graph.edge('0', '1')
graph.edge('0', '2')
graph.edge('1', '3')
graph.edge('1', '4')
graph.edge('2', '5')
graph.render('graph.png')
print(graph.source)
# Out:
# graph {
# 	0
# 	1
# 	2
# 	3
# 	4
# 	5
# 	0 -- 1
# 	0 -- 2
# 	1 -- 3
# 	1 -- 4
# 	2 -- 5
# }

# %% [markdown]
# ![dfs.png](data:image/png;base64,...)

# %% [markdown]
# # **Breadth First Search**
#
#
# Unlike the straight forward direction of DFS, BFS keeps snooping around sibling vertices until it has to go one layer deeper. BFS does not backtrack and it only goes deeper and deeper. When BFS encounter visited vertices, it simply ignores them unless it has no other vertices to visit. In that case, the traversal is over.
#
# Please refer to the website below for details
#
# https://en.wikipedia.org/wiki/Breadth-first_search

# %%
from collections import deque

class Node:
    def __init__(self, value):
        self.value = value
        self.children = []

def bfs(graph, start):
    visited = set()
    queue = deque([start])

    while queue:
        node = queue.popleft()
        if node not in visited:
            visited.add(node)
            print(node.value)

            for neighbor in node.children:
                if neighbor not in visited:
                    queue.append(neighbor)
node1 = Node(1)
node2 = Node(2)
node3 = Node(3)
node4 = Node(4)
node5 = Node(5)
node6 = Node(6)

node1.children = [node2, node3]
node2.children = [node4, node5]
node3.children = [node6]
print("BFS traversal:")
bfs(node1, start=node1)
# Out:
# BFS traversal:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
import graphviz

graph = graphviz.Graph()

graph.node('0')
graph.node('1')
graph.node('2')
graph.node('3')
graph.node('4')
graph.node('5')

graph.edge('0', '1')
graph.edge('0', '2')
graph.edge('1', '3')
graph.edge('1', '4')
graph.edge('2', '5')

graph.render('graph.png')
# Out:
# 'graph.png.pdf'

# %% [markdown]
# ![A-classical-graph-with-six-nodes-and-nine-edges.png](data:image/png;base64,...)
